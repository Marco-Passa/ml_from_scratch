# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras

housing = fetch_california_housing()
X_train_full, X_test, y_train_full, y_test = train_test_split(
 housing.data, housing.target)
X_train, X_valid, y_train, y_valid = train_test_split(
 X_train_full, y_train_full)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_valid_scaled = scaler.transform(X_valid)
X_test_scaled = scaler.transform(X_test)

# %%
input_A = keras.layers.Input(shape=[5])
input_B = keras.layers.Input(shape=[6])
hidden1 = keras.layers.Dense(30, activation="relu")(input_B)
hidden2 = keras.layers.Dense(30, activation="relu")(hidden1)
concat = keras.layers.concatenate([input_A, hidden2])
output = keras.layers.Dense(1)(concat)
aux_output = keras.layers.Dense(1)(hidden2)
model = keras.models.Model(inputs=[input_A, input_B], outputs=[output, aux_output])

# %%
model.compile(loss=["mse", "mse"], loss_weights=[0.9, 0.1], optimizer="sgd")

X_train_A, X_train_B = X_train_scaled[:, :5], X_train_scaled[:, 2:]
X_valid_A, X_valid_B = X_valid_scaled[:, :5], X_valid_scaled[:, 2:]
X_test_A, X_test_B = X_test_scaled[:, :5], X_test_scaled[:, 2:]
X_new_A, X_new_B = X_test_A[:3], X_test_B[:3]

history = model.fit([X_train_A, X_train_B], [y_train, y_train], epochs=20, validation_data=([X_valid_A, X_valid_B], [y_valid, y_valid]))

total_loss, main_loss, aux_loss = model.evaluate([X_test_A, X_test_B], [y_test, y_test])
y_pred_main, y_pred_aux = model.predict([X_new_A, X_new_B])
# Out:
# Epoch 1/20
# 363/363 [==============================] - 2s 4ms/step - loss: 1.9284 - dense_10_loss: 1.9150 - dense_11_loss: 2.0493 - val_loss: 1.3811 - val_dense_10_loss: 1.3626 - val_dense_11_loss: 1.5482
# Epoch 2/20
# 363/363 [==============================] - 1s 2ms/step - loss: 1.4149 - dense_10_loss: 1.4135 - dense_11_loss: 1.4277 - val_loss: 1.3317 - val_dense_10_loss: 1.3299 - val_dense_11_loss: 1.3487
# Epoch 3/20
# 363/363 [==============================] - 1s 3ms/step - loss: 1.3551 - dense_10_loss: 1.3520 - dense_11_loss: 1.3833 - val_loss: 1.3219 - val_dense_10_loss: 1.3204 - val_dense_11_loss: 1.3355
# Epoch 4/20
# 363/363 [==============================] - 1s 2ms/step - loss: 1.3369 - dense_10_loss: 1.3349 - dense_11_loss: 1.3545 - val_loss: 1.3189 - val_dense_10_loss: 1.3181 - val_dense_11_loss: 1.3259
# Epoch 5/20
# 363/363 [==============================] - 1s 2ms/step - loss: 1.3337 - dense_10_loss: 1.3323 - dense_11_loss: 1.3457 - val_loss: 1.3161 - val_dense_10_loss: 1.3157 - val_dense_11_loss: 1.3200
# Epoch 6/20
# 363/363 [==============================] - 1s 3ms/step - loss: 1.3437 - dense_10_loss: 1.3438 - dense_11_loss: 1.3429 - val_loss: 1.3140 - val_dense_10_loss: 1.3136 - val_dense_11_loss: 1.3182
# Epoch 7/20
# 363/363 [==============================] - 1s 2ms/step - loss: 1.3316 - dense_10_loss: 1.3309 - dense_11_loss: 1.3381 - val_loss: 1.3097 - val_dense_10_loss: 1.3093 - val_dense_11_loss: 1.3139
# Epoch 8/20
# 363/363 [==============================] - 1s 3ms/step - loss: 1.3313 - dense_10_loss: 1.3308 - dense_11_loss: 1.3360 - val_loss: 1.3163 - val_dense_10_loss: 1.3169 - val_dense_11_loss: 1.3110
# Epoch 9/20
# 363/363 [==============================] - 1s 2ms/step - loss: 1.3309 - dense_10_loss: 1.3306 - dense_11_loss: 1.3341 - val_loss: 1.3079 - val_dense_10_loss: 1.3077 - val_dense_11_loss: 1.3096
# Epoch 10/20
# 363/363 [==============================] - 1s 2ms/step - loss: 1.3311 - dense_10_loss: 1.3309 - dense_11_loss: 1.3325 - val_loss: 1.3711 - val_dense_10_loss: 1.3781 - val_dense_11_loss: 1.3088
# Epoch 11/20
# 363/363 [==============================] - 1s 3ms/step - loss: 1.3313 - dense_10_loss: 1.3313 - dense_11_loss: 1.3318 - val_loss: 1.3163 - val_dense_10_loss: 1.3167 - val_dense_11_loss: 1.3121
# Epoch 12/20
# 363/363 [==============================] - 1s 3ms/step - loss: 1.3296 - dense_10_loss: 1.3295 - dense_11_loss: 1.3310 - val_loss: 1.3100 - val_dense_10_loss: 1.3102 - val_dense_11_loss: 1.3082
# Epoch 13/20
# 363/363 [==============================] - 1s 4ms/step - loss: 1.3295 - dense_10_loss: 1.3294 - dense_11_loss: 1.3304 - val_loss: 1.3089 - val_dense_10_loss: 1.3089 - val_dense_11_loss: 1.3082
# Epoch 14/20
# 363/363 [==============================] - 1s 3ms/step - loss: 1.3277 - dense_10_loss: 1.3276 - dense_11_loss: 1.3288 - val_loss: 1.3095 - val_dense_10_loss: 1.3099 - val_dense_11_loss: 1.3065
# Epoch 15/20
# 363/363 [==============================] - 1s 3ms/step - loss: 1.3294 - dense_10_loss: 1.3294 - dense_11_loss: 1.3297 - val_loss: 1.3082 - val_dense_10_loss: 1.3085 - val_dense_11_loss: 1.3051
# Epoch 16/20
# 363/363 [==============================] - 1s 3ms/step - loss: 1.3311 - dense_10_loss: 1.3312 - dense_11_loss: 1.3303 - val_loss: 1.3068 - val_dense_10_loss: 1.3070 - val_dense_11_loss: 1.3052
# Epoch 17/20
# 363/363 [==============================] - 1s 3ms/step - loss: 1.3330 - dense_10_loss: 1.3334 - dense_11_loss: 1.3293 - val_loss: 1.3079 - val_dense_10_loss: 1.3081 - val_dense_11_loss: 1.3060
# Epoch 18/20
# 363/363 [==============================] - 1s 3ms/step - loss: 1.3303 - dense_10_loss: 1.3305 - dense_11_loss: 1.3287 - val_loss: 1.3088 - val_dense_10_loss: 1.3091 - val_dense_11_loss: 1.3054
# Epoch 19/20
# 363/363 [==============================] - 1s 2ms/step - loss: 1.3322 - dense_10_loss: 1.3325 - dense_11_loss: 1.3291 - val_loss: 1.3090 - val_dense_10_loss: 1.3094 - val_dense_11_loss: 1.3055
# Epoch 20/20
# 363/363 [==============================] - 1s 2ms/step - loss: 1.3277 - dense_10_loss: 1.3276 - dense_11_loss: 1.3284 - val_loss: 1.3058 - val_dense_10_loss: 1.3059 - val_dense_11_loss: 1.3050
# 162/162 [==============================] - 0s 2ms/step - loss: 1.3647 - dense_10_loss: 1.3645 - dense_11_loss: 1.3668
# 1/1 [==============================] - 0s 80ms/step

# %%
y_pred_main
# Out:
# array([[1.9267693],
#        [2.143165 ],
#        [2.069002 ]], dtype=float32)

# %%
y_pred_aux
# Out:
# array([[1.9115413],
#        [2.1942244],
#        [2.1320603]], dtype=float32)
